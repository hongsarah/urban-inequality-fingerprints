# %%
import requests
import pandas as pd
import os
import sys
sys.path.insert(0, 'src')
from api_keys import GOOGLE_API_KEY

os.makedirs('data/images', exist_ok=True)

# Test with just one LSOA
test = pd.read_csv('data/test_lsoas.csv')
row = test.iloc[0]

url = (
    f"https://maps.googleapis.com/maps/api/streetview"
    f"?size=640x640"
    f"&location={row['lat']},{row['lon']}"
    f"&heading=0"
    f"&pitch=0"
    f"&fov=90"
    f"&key={GOOGLE_API_KEY}"
)

response = requests.get(url)
print(f"Status code: {response.status_code}")
print(f"Image size: {len(response.content)} bytes")

if len(response.content) > 10000:
    with open('data/images/test_image.jpg', 'wb') as f:
        f.write(response.content)
    print("Success! Open data/images/test_image.jpg to see it")
else:
    print("Failed - image too small, likely no Street View coverage here")
# Out:
# Status code: 200
# Image size: 42325 bytes
# Success! Open data/images/test_image.jpg to see it

# %%
import requests
import pandas as pd
import os
import time
import sys
sys.path.insert(0, 'src')
from api_keys import GOOGLE_API_KEY

test = pd.read_csv('data/test_lsoas.csv')
os.makedirs('data/images', exist_ok=True)

headings = [0, 90, 180, 270]
total_success = 0
total_failed = 0

for idx, row in test.iterrows():
    lsoa_code = row['LSOA11CD']
    
    for heading in headings:
        filename = f"data/images/{lsoa_code}_{heading}.jpg"
        
        # Skip if already downloaded
        if os.path.exists(filename):
            total_success += 1
            continue
        
        url = (
            f"https://maps.googleapis.com/maps/api/streetview"
            f"?size=640x640"
            f"&location={row['lat']},{row['lon']}"
            f"&heading={heading}"
            f"&pitch=0"
            f"&fov=90"
            f"&key={GOOGLE_API_KEY}"
        )
        
        response = requests.get(url)
        
        if response.status_code == 200 and len(response.content) > 10000:
            with open(filename, 'wb') as f:
                f.write(response.content)
            total_success += 1
        else:
            total_failed += 1
        
        time.sleep(0.3)
    
    # Print progress every 50 LSOAs
    if (idx + 1) % 50 == 0:
        print(f"Progress: {idx + 1}/2000 LSOAs | Success: {total_success} | Failed: {total_failed}")

print(f"\nDone! {total_success} downloaded, {total_failed} failed")
# Out:
# Progress: 50/500 LSOAs | Success: 180 | Failed: 20
# Progress: 100/500 LSOAs | Success: 344 | Failed: 56
# Progress: 150/500 LSOAs | Success: 528 | Failed: 72
# Progress: 200/500 LSOAs | Success: 712 | Failed: 88
# Progress: 250/500 LSOAs | Success: 888 | Failed: 112
# Progress: 300/500 LSOAs | Success: 1072 | Failed: 128
# Progress: 350/500 LSOAs | Success: 1260 | Failed: 140
# Progress: 400/500 LSOAs | Success: 1452 | Failed: 148
# Progress: 450/500 LSOAs | Success: 1620 | Failed: 180
# Progress: 500/500 LSOAs | Success: 1792 | Failed: 208
# Progress: 550/500 LSOAs | Success: 1988 | Failed: 212
# Progress: 600/500 LSOAs | Success: 2160 | Failed: 240
# Progress: 650/500 LSOAs | Success: 2336 | Failed: 264
# Progress: 700/500 LSOAs | Success: 2524 | Failed: 276
# Progress: 750/500 LSOAs | Success: 2708 | Failed: 292
# Progress: 800/500 LSOAs | Success: 2884 | Failed: 316
# Progress: 850/500 LSOAs | Success: 3064 | Failed: 336
# Progress: 900/500 LSOAs | Success: 3252 | Failed: 348
# Progress: 950/500 LSOAs | Success: 3436 | Failed: 364
# Progress: 1000/500 LSOAs | Success: 3592 | Failed: 408
# Progress: 1050/500 LSOAs | Success: 3772 | Failed: 428
# Progress: 1100/500 LSOAs | Success: 3948 | Failed: 452
# Progress: 1150/500 LSOAs | Success: 4120 | Failed: 480
# Progress: 1200/500 LSOAs | Success: 4296 | Failed: 504
# Progress: 1250/500 LSOAs | Success: 4456 | Failed: 544
# Progress: 1300/500 LSOAs | Success: 4632 | Failed: 568
# Progress: 1350/500 LSOAs | Success: 4816 | Failed: 584
# Progress: 1400/500 LSOAs | Success: 4976 | Failed: 624
# Progress: 1450/500 LSOAs | Success: 5140 | Failed: 660
# Progress: 1500/500 LSOAs | Success: 5284 | Failed: 716
# Progress: 1550/500 LSOAs | Success: 5464 | Failed: 736
# Progress: 1600/500 LSOAs | Success: 5644 | Failed: 756
# Progress: 1650/500 LSOAs | Success: 5820 | Failed: 780
# Progress: 1700/500 LSOAs | Success: 5984 | Failed: 816
# Progress: 1750/500 LSOAs | Success: 6168 | Failed: 832
# Progress: 1800/500 LSOAs | Success: 6312 | Failed: 888
# Progress: 1850/500 LSOAs | Success: 6464 | Failed: 936
# Progress: 1900/500 LSOAs | Success: 6620 | Failed: 980
# Progress: 1950/500 LSOAs | Success: 6768 | Failed: 1032
# Progress: 2000/500 LSOAs | Success: 6924 | Failed: 1076
#
# Done! 6924 downloaded, 1076 failed

# %%
import pandas as pd
test = pd.read_csv('data/test_lsoas.csv')
print(f'Rows in CSV: {len(test)}')

# %%
print(len(test))
print(test.tail(3))
# Out:
# 2000
#        LSOA11CD  IMD19        lat       lon
# 1997  E01030406  30804  51.357950 -0.246388
# 1998  E01000874  30591  51.552947 -0.193397
# 1999  E01002512  29384  51.553860 -0.469262
